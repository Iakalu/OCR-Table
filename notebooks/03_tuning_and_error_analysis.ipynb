# %% [markdown]
# # Tuning va Error Analysis
#
# Notebook nay tong hop cach chinh tham so cho cac dang bang khac nhau.

# %%
parameter_guide = {
    'ruled_table': {
        'merge_tolerance': '4-8',
        'cell_padding': '2-4',
        'note': 'Bang co duong ke ro, heuristic co the lam baseline tot.'
    },
    'borderless_table': {
        'image_size': '1024-1600',
        'structure_threshold': '0.35-0.50',
        'note': 'Can model DL va OCR word boxes de suy row/column.'
    },
    'scanned_noisy_table': {
        'deskew': True,
        'merge_tolerance': '8-16',
        'augmentation': 'blur, rotation, perspective, brightness'
    },
    'financial_table': {
        'dataset': 'FinTabNet',
        'postprocess': 'normalize currency, percentage, negative numbers'
    }
}
parameter_guide

# %% [markdown]
# ## Quy tac debug nhanh
#
# 1. Miss table: giam detection confidence hoac tang image size.
# 2. False positive: tang detection confidence, them negative samples.
# 3. Sai hang/cot: dieu chinh merge tolerance hoac fine-tune structure model.
# 4. OCR mat chu: tang cell padding.
# 5. OCR nham border: giam padding hoac remove border truoc OCR.
# 6. Sai merged cell: danh gia bang HTML/JSON, khong ep CSV qua som.
